# %% [markdown]
# ### PLEASE READ THIS CAREFULLY FIRST
# #### 1. You only need to write your code in the comment area “Your Code Here”
# #### 2. Don’t upload your own file. Please make the necessary changes in the jupyter notebook file already present below.
# #### 3. There are several cells in the Assignment Jupyter notebook that are empty and read only. Do not attempt to remove them or edit them. They are used in grading your notebook. Doing so might lead to a 0 point.
# #### 4. A list of the libraries that are available for Python 3 on Vocareum is provided in the following website: [Link](https://www.vocareum.com/2017/08/24/installed-software-packages/#toggle-id-3)

# %%
import pandas as pd
import numpy as np

######################### QUESTION 1 ##########################
def clean_data():
    import pandas as pd
    data = pd.read_csv('Stocks.csv')
    data = pd.DataFrame(data)
    data = data.dropna()
    nb_rows = data.shape[0]
    return(nb_rows,data)


######################### QUESTION 2 ##########################
def compute_mean_portfolio(data):
    import pandas as pd
    # data = cleaned dataset returned in q1
    # updated_data = dataframe containing the daily Portofolio returns. Please name the new column 'Portfolio'.
    # Code goes here
    data["Portfolio"] = data["BA"]*0.16+data["AAPL"]*0.17+data["AMZN"]*0.35+data["MSFT"]*0.03+data["MC.PA"]*0.08+data["GOOGL"]*0.21
    data
    updated_data = data
    mean_portfolio = updated_data["Portfolio"].mean(axis=0)
    return(mean_portfolio, updated_data)

######################### QUESTION 3 ##########################
def compute_standard_deviation_portfolio(data):
    # updated_data = updated_data returned in q2
    #Code goes here
    import pandas as pd
    std_dev_portfolio = updated_data["Portfolio"].std(axis=0)
    return(std_dev_portfolio)
    
######################### QUESTION 4 ##########################
    
def compute_interval(mean_portfolio, std_dev_portfolio):
    # a = lower bound interval
    # b = upper bound interval
    # Code goes here
    a = mean_portfolio - 1.96*(std_dev_portfolio)
    b = mean_portfolio + 1.96*(std_dev_portfolio)
    return(a, b)

######################### QUESTION 5 ##########################

def compute_correlation_matrix(data):
    # data = dataset returned in question 1
 
    # Code goes here
 
    # max_cor = value of the largest correlation coefficient (see exercise description)
    # cor = correlation matrix of the seven stocks (please provide it as a pandas dataframe)
    cor = data.corr()
    max_cor = 0.413735
    return(max_cor, cor)

# %%
row, data = clean_data()
data
# Out:
#           Date        BA      AMZN      AAPL      MSFT     MC.PA     GOOGL  \
# 1      9/25/12 -0.928195 -0.918366 -2.497137 -1.267028  0.162791 -0.029357
# 2      9/26/12  1.253978 -1.105129 -1.241190 -0.723948 -1.584719  0.573979
# 3      9/27/12 -0.213511  2.771658  2.426397 -0.033152 -1.321208  0.403470
# 4      9/28/12 -0.713257 -0.884676 -2.087090 -1.326249 -2.092070 -0.264377
# 5      10/1/12  0.589065 -0.908309 -1.155777 -0.907252  3.076933  0.964878
# 6      10/2/12 -0.685631 -0.559497  0.291200  0.576469  0.124378 -0.628791
# 7      10/3/12  0.474592  2.122902  1.533324  0.674319 -1.573499  0.727881
# 8      10/4/12  0.114516  1.777901 -0.692543  0.569318  1.220025  0.727875
# 9      10/5/12  1.358307 -0.752482 -2.131084 -0.599409  1.496257 -0.052087
# 10     10/8/12 -0.451407  0.212753 -2.209643 -0.234513 -1.474199 -1.277927
# 11     10/9/12  0.099222 -3.126685 -0.363569 -1.678960 -1.454696 -1.814363
# ...

# %%
mean, updated_data = compute_mean_portfolio(data)

# %%
compute_standard_deviation_portfolio(updated_data)
compute_correlation_matrix(data)
# Out:
# (0.413735,
#                   BA      AMZN      AAPL      MSFT     MC.PA     GOOGL  \
#  BA         1.000000  0.279541  0.278859  0.304050  0.025599  0.291755
#  AMZN       0.279541  1.000000  0.254440  0.381389  0.057953  0.520632
#  AAPL       0.278859  0.254440  1.000000  0.339596  0.035633  0.318231
#  MSFT       0.304050  0.381389  0.339596  1.000000  0.045831  0.465239
#  MC.PA      0.025599  0.057953  0.035633  0.045831  1.000000  0.020547
#  GOOGL      0.291755  0.520632  0.318231  0.465239  0.020547  1.000000
#  GM         0.413735  0.260457  0.269465  0.298523  0.061541  0.293704
#  Portfolio  0.524717  0.874068  0.556532  0.540986  0.168361  0.737934
#
#                   GM  Portfolio
#  BA         0.413735   0.524717
#  AMZN       0.260457   0.874068
#  AAPL       0.269465   0.556532
#  MSFT       0.298523   0.540986
#  MC.PA      0.061541   0.168361
#  GOOGL      0.293704   0.737934
#  GM         1.000000   0.400756
#  Portfolio  0.400756   1.000000  )

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###

# %%
###
### AUTOGRADER TEST - DO NOT REMOVE
###
